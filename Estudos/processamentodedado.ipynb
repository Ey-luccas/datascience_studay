# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# Importação do Dataset

# %%
cvs_credit = pd.read_csv("C:/Users/eyluc/Documents/ESTUDO -- 'data scientist'/Eydatascience/Estudos/Datasets/credit_dt.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cvs_credit = pd.read_csv("C:/Users/eyluc/Documents/ESTUDO -- 'data scientist'/Eydatascience/Estudos/Datasets/credit_dt.csv")
#
# NameError: name 'pd' is not defined

# %%
cvs_credit.head(10)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# ...

# %%
cvs_credit.tail(10)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32571          60          45600                  RENT                1.0
# 32572          52          52000                   OWN                0.0
# 32573          56          90000              MORTGAGE                0.0
# 32574          52          65004                  RENT                4.0
# 32575          52          64500                  RENT                0.0
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32571          VENTURE          B      20000          10.00            1
# ...

# %%
cvs_credit.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
display(cvs_credit[cvs_credit['person_age'] <= 20])
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1313           20          64000                  RENT                3.0
# 3851           20          32652              MORTGAGE                0.0
# 5648           20          94000                  RENT                4.0
# 7327           20          42000                  RENT                4.0
# 7748           20          34800                  RENT                3.0
# 9926           20          65000              MORTGAGE                4.0
# 11889          20          77000              MORTGAGE                4.0
# 11902          20          77052              MORTGAGE                4.0
# 12943          20          85920              MORTGAGE                3.0
# 13918          20          98000              MORTGAGE                4.0
# 14827          20         115731              MORTGAGE                4.0
# 15417          20         135000              MORTGAGE                1.0
# ...

# %%
quantidade_age20 = cvs_credit[(cvs_credit['person_age'] >= 30) | (cvs_credit['person_age']<=50) ].index
print(quantidade_age20)
# Out:
# RangeIndex(start=0, stop=32581, step=1)

# %%
count = 0
while (count >= 10):
  print('eu amo lais')
count = count + 1

# %%
quantidade = (cvs_credit['person_age'] <= 20).sum()
print(f"Número de pessoas com exatamente 20 anos: {quantidade}")
# Out:
# Número de pessoas com exatamente 20 anos: 15

# %%
quantidade_age20 = cvs_credit[(cvs_credit['person_age'] >= 30) | (cvs_credit['person_age']<=50) ].sum()
print(quantidade_age20)
# Out:
# person_age                                                               903621
# person_income                                                        2152784638
# person_home_ownership         RENTOWNMORTGAGERENTRENTOWNRENTRENTRENTOWNRENTO...
# person_emp_length                                                      151766.0
# loan_intent                   PERSONALEDUCATIONMEDICALMEDICALMEDICALVENTUREE...
# loan_grade                    DBCCCABBADBAAEABAFDBAEDADCEABCBACCCAEDDDEBAFBD...
# loan_amnt                                                             312431300
# loan_int_rate                                                         324459.59
# loan_status                                                                7108
# loan_percent_income                                                      5545.4
# cb_person_default_on_file     YNNNYNNNNNNNNNNNNNNNNYNNYNYNNYNNYNNNNYYNNNNYNN...
# cb_person_cred_hist_length                                               189107
# dtype: object
