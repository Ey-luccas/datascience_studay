# %% [markdown]
# puxando o arquivo principal com a intalação do dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import StandardScaler

# %%
dataframe_credit = pd.read_csv("C:/Users/eyluc/Documents/ESTUDO -- 'data scientist'/Eydatascience/Estudos/Datasets/csv/credit_dt.csv")

# %%
display(dataframe_credit)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
dataframe_credit.head(10)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# ...

# %%
dataframe_credit.tail(8)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32573          56          90000              MORTGAGE                0.0
# 32574          52          65004                  RENT                4.0
# 32575          52          64500                  RENT                0.0
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32573         PERSONAL          A       7200           6.17            0
# 32574         PERSONAL          D      20000          15.58            1
# 32575        EDUCATION          B       5000          11.26            0
# ...

# %%
dataframe_credit.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
dataframe_credit1 = dataframe_credit.drop(
    ['cb_person_cred_hist_length', 'loan_int_rate', 'loan_percent_income', 
     'person_home_ownership', 'loan_intent', 'loan_grade', 
     'cb_person_default_on_file', 'person_emp_length'],  
    axis=1
).rename(columns={
    "person_age": "age", 
    "person_income": "income", 
    "loan_amnt": "loan", 
    "loan_status": "default"
})

# %%
dataframe_credit1
# Out:
#        age  income   loan  default
# 0       22   59000  35000        1
# 1       21    9600   1000        0
# 2       25    9600   5500        1
# 3       23   65500  35000        1
# 4       24   54400  35000        1
# ...    ...     ...    ...      ...
# 32576   57   53000   5800        0
# 32577   54  120000  17625        0
# 32578   65   76000  35000        1
# 32579   56  150000  15000        0
# 32580   66   42000   6475        0
#
# [32581 rows x 4 columns]

# %%
dataframe_credit1.sum()
# Out:
# age            903621
# income     2152784638
# loan        312431300
# default          7108
# dtype: int64

# %%
dataframe_credit1[dataframe_credit1['age'] > 100]
# Out:
#        age   income   loan  default
# 81     144   250000   4800        0
# 183    144   200000   6000        0
# 575    123    80004  20400        0
# 747    123    78000  20000        0
# 32297  144  6000000   5000        0

# %%
i = dataframe_credit1['age'] > 100
incorretos = []
corretos = []
for id, ii in enumerate(i):
  if ii == True: 
    incorretos.append(id)
  else: 
    corretos.append(id)

print(incorretos)
# Out:
# [81, 183, 575, 747, 32297]

# %%
dataframe_credit1.iloc[81, 183, 575, 747, 32297]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dataframe_credit1.iloc[81, 183, 575, 747, 32297]
#
# File c:\Users\eyluc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\eyluc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
# ...

# %%
for i in incorretos: 
  dt= dataframe_credit1.iloc[i]
  print(dt)
  print("\n")
# Out:
# age           144
# income     250000
# loan         4800
# default         0
# Name: 81, dtype: int64
#
#
# age           144
# income     200000
# loan         6000
# default         0
# Name: 183, dtype: int64
#
#
# age          123
# income     80004
# loan       20400
# default        0
# Name: 575, dtype: int64
#
#
# age          123
# income     78000
# loan       20000
# default        0
# Name: 747, dtype: int64
#
#
# age            144
# income     6000000
# loan          5000
# default          0
# Name: 32297, dtype: int64

# %%
dataframe_credit1['age'].mean()
# Out:
# np.float64(27.73459992019889)

# %%
dataframe_credit1.loc[dataframe_credit1['age'] > 100, 'age'] = 27

# %%
dataframe_credit1.isnull().sum()
# Out:
# age        0
# income     0
# loan       0
# default    0
# dtype: int64

# %%
type(dataframe_credit1)
# Out:
# pandas.core.frame.DataFrame

# %%
X_credit = dataframe_credit1.iloc[:, 0:3].values

# %%
X_credit
# Out:
# array([[    22,  59000,  35000],
#        [    21,   9600,   1000],
#        [    25,   9600,   5500],
#        ...,
#        [    65,  76000,  35000],
#        [    56, 150000,  15000],
#        [    66,  42000,   6475]], shape=(32581, 3))

# %%
type(X_credit)
# Out:
# numpy.ndarray

# %%
y_credit = dataframe_credit1.iloc[:, 3].values

# %%
y_credit
# Out:
# array([1, 0, 1, ..., 1, 0, 0], shape=(32581,))

# %%
type(y_credit)
# Out:
# numpy.ndarray

# %%
from sklearn.preprocessing import StandardScaler 
scaler_credit = StandardScaler()
X_credit = scaler_credit.fit_transform(X_credit)

# %%
X_credit[:,0].min(), X_credit[:,1].min(), X_credit[:,2].min()
# Out:
# (np.float64(-1.2439403067574821),
#  np.float64(-1.0014952772370846),
#  np.float64(-1.4377390104182448))

# %%
X_credit
# Out:
# array([[-0.9215897 , -0.11414329,  4.01940376],
#        [-1.082765  , -0.91114671, -1.35864998],
#        [-0.4380638 , -0.91114671, -0.64684875],
#        ...,
#        [ 6.00894829,  0.16012914,  4.01940376],
#        [ 4.55837057,  1.35402091,  0.85584274],
#        [ 6.17012359, -0.38841572, -0.49262515]], shape=(32581, 3))

# %%
from sklearn.model_selection import train_test_split

# %%
X_credit_treinamento, X_credit_teste, y_credit_treinamento, y_credit_teste = train_test_split(X_credit, y_credit, test_size= 0.25, random_state= 0)

# %%
X_credit_treinamento
# Out:
# array([[-0.9215897 ,  0.22466383, -0.37003716],
#        [ 0.36781271,  0.01492609,  0.06495248],
#        [-0.4380638 , -0.1115619 ,  1.10892762],
#        ...,
#        [-0.9215897 , -0.44488358, -0.09322557],
#        [-0.7604144 , -0.38841572,  0.06495248],
#        [-0.7604144 , -0.5174851 ,  0.21522163]], shape=(24435, 3))

# %%
X_credit_teste
# Out:
# array([[-0.5992391 , -0.39970929, -1.13720071],
#        [-0.5992391 ,  0.3053322 ,  2.43762325],
#        [-0.5992391 ,  0.35373321, -0.56775973],
#        ...,
#        [ 0.36781271, -0.227079  , -0.09322557],
#        [-0.5992391 ,  0.03105976, -0.56775973],
#        [-0.4380638 , -0.03347493,  1.64673299]], shape=(8146, 3))

# %%
import pickle

# %%
with open('credit.pkl', mode='wb') as f: 
  pickle.dump([X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_teste], f)
