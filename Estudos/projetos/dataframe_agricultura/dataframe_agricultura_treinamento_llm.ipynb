# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
base_agricultura = pd.read_csv(r"C:\Users\eyluc\Documents\ESTUDO -- 'data scientist'\Eydatascience\Estudos\Datasets\csv\agricultural_dataset.csv")

# %%
display(base_agricultura)
# Out:
#      conversation_id                                             prompt  \
# 0     Conversation 1  I'm a soil scientist working with precision ag...
# 1     Conversation 2  I'm a urban farmer in Pampas, Argentina intere...
# 2     Conversation 3  I'm researching sustainable water management f...
# 3     Conversation 4  Our syntropic farming cooperative in Alberta, ...
# 4     Conversation 5  As a biological farmer in Pannonian Plain, Hun...
# ..               ...                                                ...
# 153  Conversation 36  How might the application of FFJ and FAA in co...
# 154  Conversation 37  In a KNF system, how might the use of Indigeno...
# 155  Conversation 38  How might the long-term use of KNF practices a...
# 156  Conversation 39  In a KNF system, how might the interaction bet...
# 157  Conversation 40  How might the use of Fermented Plant Juice (FP...
#
#                                               response
# ...

# %%
base_agricultura1 = base_agricultura.drop(['conversation_id'], axis=1)

# %%
base_agricultura1
# Out:
#                                                 prompt  \
# 0    I'm a soil scientist working with precision ag...
# 1    I'm a urban farmer in Pampas, Argentina intere...
# 2    I'm researching sustainable water management f...
# 3    Our syntropic farming cooperative in Alberta, ...
# 4    As a biological farmer in Pannonian Plain, Hun...
# ..                                                 ...
# 153  How might the application of FFJ and FAA in co...
# 154  In a KNF system, how might the use of Indigeno...
# 155  How might the long-term use of KNF practices a...
# 156  In a KNF system, how might the interaction bet...
# 157  How might the use of Fermented Plant Juice (FP...
#
#                                               response
# 0    <thinking>\nThe user is asking how to use swal...
# 1    <thinking>\nThe user is asking for guidance on...
# 2    <thinking>\nThe user is asking for sustainable...
# 3    <thinking>\nThe user is asking about implement...
# ...
